# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from IPython.display import display

# %%
url = "https://www.jobkorea.co.kr/Search/?stext=데이터분석"  # 원하는 검색어에 맞게 설정
headers = {'User-Agent': 'Mozilla/5.0'}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# 결과 저장
results = []

# 채용 리스트 선택
articles = soup.select('article.list-item')

for item in articles:
    company = item.select_one('.corp-name-link')
    title = item.select_one('.information-title-link')
    body = item.select_one('.chip-information-group')
    relative_url = item.get('data-gavirturl')  


    data = {
        'Site': 'JobKorea',
        'Col_company': company.get_text(strip=True) if company else None,
        'Col_Recruit': title.get_text(strip=True) if title else None,
        'Col_detail': body.get_text(strip=True) if body else None,
        'Col_url': relative_url
    }
    results.append(data)

# 출력
df = pd.DataFrame(results)

# %%
df
# Out:
#         Site                     Col_company  \
# 0   JobKorea                         더치트주식회사
# 1   JobKorea                         넛지헬스케어㈜
# 2   JobKorea                        ㈜메디젠휴먼케어
# 3   JobKorea                         넛지헬스케어㈜
# 4   JobKorea                              연이
# 5   JobKorea                            한패스㈜
# 6   JobKorea                          휴먼교육센터
# 7   JobKorea                       (주)상상에프앤비
# 8   JobKorea                             ㈜큐핏
# 9   JobKorea                        ㈜케이씨지소프트
# 10  JobKorea                           ㈜메이크인
# 11  JobKorea                         ㈜이젠아카데미
# 12  JobKorea                         한국정보기술㈜
# 13  JobKorea               부산대학교 지능물류빅데이터연구소
# 14  JobKorea                        ㈜파오스파트너스
# 15  JobKorea                            글로빛㈜
# 16  JobKorea                         잡코리아(유)
# 17  JobKorea                            ㈜써치엠
# 18  JobKorea                            코웨이㈜
# 19  JobKorea                   ㈜싸이트플래닝건축사사무소
# 20  JobKorea                     ㈔한국산업기술진흥협회
# 21  JobKorea                             페브샵
# 22  JobKorea                           기획사이다
# 23  JobKorea                         한솔생명과학㈜
# 24  JobKorea                      ㈜대덕분석기술연구원
# 25  JobKorea                     농업회사법인이룸팜스㈜
# 26  JobKorea                          삼성중공업㈜
# 27  JobKorea                        모두투어네트워크
# 28  JobKorea                            ㈜비알팜
# 29  JobKorea                          지멘스에너지
# 30  JobKorea                            None
# 31  JobKorea                            None
# 32  JobKorea                            None
# 33  JobKorea                            None
# 34  JobKorea                            None
# 35  JobKorea                            None
# 36  JobKorea                            None
# 37  JobKorea                            None
# 38  JobKorea  #연구보조 및 측정,증량작업#고졸및전문대졸까지#연구보조
# 39  JobKorea                          휴먼교육센터
# 40  JobKorea                          휴먼교육센터
# 41  JobKorea            디오브이매니지먼트 코리아 유한책임회사
# 42  JobKorea                       뉴클리어엔지니어링
# 43  JobKorea                           데이터분석
# 44  JobKorea                    비앤브이솔루션 주식회사
# 45  JobKorea  #연구보조 및 측정,증량작업#고졸및전문대졸까지#경력쌓기
# 46  JobKorea  #연구보조 및 측정,증량작업#고졸및전문대졸까지#경력쌓기
# 47  JobKorea                           ㈜메트릭스
# 48  JobKorea  #연구보조 및 측정,증량작업#고졸및전문대졸까지#연구보조
# 49  JobKorea                          휴먼교육센터
#
#                                        Col_Recruit  \
# 0   데이터 애널리스트 /데이터분석전문가 / 통계 전문가 / Data Analyst (통
# 1                        [캐시워크-병역특례]데이터분석담당 산업기능요원
# 2                            메디젠휴먼케어데이터분석담당 경력직 채용
# 3                           [캐시워크]데이터분석담당 채용전환형 인턴
# 4                       데이터분석준전문가 자격증 온라인 강의 교사 채용
# 5           [한패스(주)/데이터분석팀] Google Analytics데이터분석가
# 6           [국비무료/숙식무료]AI/빅데이터분석/풀스택/KDT심화(무료숙식제공)
# 7              배달전문 프랜차이즈 기업 상상에프앤비 배달앱데이터분석전문가 채용
# 8                      보험 상품 업무 및데이터분석신입 및 경력사원 채용
# 9                  모빌리티 플랫폼을 혁신할 기술영업 전문가와데이터분석전문가
# 10                  [자체직전환/신입가능/여의도]나이스평가정보데이터분석채용
# 11                 ADSP자격증 빅데이터분석주말(토요일) 강의 강사님 채용
# 12                [한국정보기술(주)] 수도권본부-교통센터데이터분석인력 채용
# 13          [부산대KDT]개발자과정교육생모집(AI데이터분석풀스택웹개발자양성과정)
# 14                 (주)파오스파트너스 -DB관리, DB생성, DB분석 채용
# 15          [글로빛] 빅데이터분석,AI(머신러닝,딥러닝) 가능한 박사님 모십니다
# 16                          [잡코리아] 영업기획 담당 (3년 이상)
# 17         [마케팅지원팀-신입/경력] 매체정산/영업지원/데이터분석/매체커뮤니케이션
# 18        [코웨이]25년 3월 계약직 채용(업무지원/데이터분석/실험보조/품질관리)
# 19                 도시공학&데이터분석공고 모집 (정규직, 경력직) [부산]
# 20                   한국산업기술진흥협회 정규직 공개채용 (일반행정/전산)
# 21                                영상편집/제작자 신입 및 경력
# 22                 [신입연봉 3,600] 누구보다 평범한 광고 기획자 모집
# 23                           2025년 화장품 각 부문 정규직 채용
# 24                     [DARI] 고체연료팀 시험분석 업무 담당자 채용
# 25                                 현장물류 재고,입/출고 관리
# 26                                  경력사원 채용 - 경영지원
# 27                             [모두투어] 채용 연계형 인턴 채용
# 28           생산관리/생산부/제조생산/구매/QA/공무/웹 관리자 신입/경력 채용
# 29                                [외국계 기업] 각 부문 채용
# 30                       2025년 상반기 라인그룹 경력/신입 공개채용
# 31                                2025년 신입/경력사원 채용
# 32                                   2025년 각 부문 채용
# 33                            2025년 상반기 신입/경력 공개채용
# 34                        2025년 상반기 부문별 대졸 신입사원 채용
# 35                                 2025 신입 및 경력 채용
# 36                                   신입 및 경력 사원 채용
# 37                                  각 부문별 신입/경력 채용
# 38           광학필름 연구보조 분석,측정 및 배합액 레진 작업등, 초보가능 급급
# 39        [국비무료/기숙사무료] AI심화/데이터분석/인공지능/풀스택(무료숙식제공)
# 40        [국비무료/기숙사무료] AI심화/데이터분석/인공지능/풀스택(무료숙식제공)
# 41             시장분석부터 딜소싱까지, AI/기술 기반 비즈니스 컨설턴트 모집
# 42                               야외추적자실험 지원 및 GC분석
# 43          [SK자회사/2개월 단기] 데이터 분석 및 수집 아르바이트 직원 채용
# 44        인천지역 중, 고등학교 빅데이터 / 인공지능 강사 모집 +[강사풀 등록]
# 45            광학필름 연구보조 및 레진 실험 준비 및 측정등 보조업무 초보가능
# 46           필름배합액 연구보조 및 레진 실험 준비 및 측정등 보조업무 초보가능
# 47        [주1회 재택지원/사무보조] 데이터 분석 및 온라인 모니터링 담당자 채용
# 48           광학필름 연구보조 분석,측정 및 배합액 레진 작업등, 초보가능 급급
# 49        [국비무료/기숙사무료] AI심화/데이터분석/인공지능/풀스택(무료숙식제공)
#
#                                  Col_detail  \
# 0                    경력무관대졸↑정규직 외서울 구로구D-22
# 1                     경력무관학력무관병역특례서울 강남구D-5
# 2                     경력3년↑석사↑정규직서울 송파구D-39
# 3                          신입대졸↑인턴서울 강남구D-8
# 4                   경력2년↑학력무관프리랜서서울 광진구D-28
# 5                        경력학력무관정규직서울 성동구D-4
# 6              신입·경력학력무관연수생/교육생서울 영등포구 외D-3
# 7                      경력학력무관정규직경기 남양주시D-12
# 8                   신입·경력2년↑대졸↑정규직서울 종로구D-8
# 9                    경력3년↑초대졸↑정규직서울 성동구상시채용
# 10                경력무관초대졸↑계약직 외서울 영등포구 외D-3
# 11                신입·경력초대졸↑정규직 외서울 서초구 외D-6
# 12                     경력무관학력무관계약직경기 성남시D-2
# 13                       신입대졸↑정규직부산 금정구상시채용
# 14                    경력무관초대졸↑정규직서울 용산구D-14
# 15                    경력무관박사↑프리랜서서울 서초구상시채용
# 16                    경력3년↑학력무관정규직서울 서초구D-5
# 17                    신입·경력초대졸↑정규직서울 강남구D-2
# 18                      경력학력무관계약직서울 구로구상시채용
# 19                     경력3년↑대졸↑정규직부산 동구D-15
# 20                            신입대졸↑정규직서울D-7
# 21                      경력무관초대졸↑정규직경기 외D-12
# 22                        경력무관학력무관정규직인천D-12
# 23                     신입·경력학력무관정규직 외경기D-18
# 24                       경력무관대졸↑정규직대전 외상시채용
# 25                        경력학력무관정규직전남 외D-14
# 26                             경력정규직경남 외D-8
# 27                            신입초대졸↑인턴서울D-5
# 28                     신입·경력학력무관정규직 외강원D-15
# 29                     신입·경력초대졸↑정규직 외서울D-12
# 30                                     D-12
# 31                                     D-13
# 32                                     D-12
# 33                                      D-9
# 34                                     D-13
# 35                                     D-20
# 36                                     D-30
# 37                                     D-29
# 38  연봉29,000,000원경기 오산시 오산동등록일 6시간전마감일 상시모집
# 39                    충남 아산시 배방읍등록일 3/30D-3
# 40                경기 안산시 상록구 본오동등록일 3/30D-3
# 41      건별10,030원서울 강남구 삼성동등록일 3/27마감일 상시모집
# 42   월급2,096,270원대전 유성구 구룡동등록일 3/31마감일 상시모집
# 43   월급2,096,270원서울 강남구 삼성동등록일 3/29마감일 상시모집
# 44           시급30,000원인천 계양구 박촌동등록일 3/24D-3
# 45  연봉29,000,000원경기 오산시 오산동등록일 3/24마감일 상시모집
# 46  연봉29,000,000원경기 평택시 진위면등록일 3/24마감일 상시모집
# 47        월급2,400,000원서울 서초구 양재동등록일 3/22D-6
# 48  연봉29,000,000원경기 평택시 진위면등록일 3/31마감일 상시모집
# 49                경기 수원시 영통구 이의동등록일 3/30D-3
#
#                                               Col_url
# 0   https://www.jobkorea.co.kr/virtual/Recruit/GI_...
# 1   https://www.jobkorea.co.kr/virtual/Recruit/GI_...
# 2   https://www.jobkorea.co.kr/virtual/Recruit/GI_...
# 3   https://www.jobkorea.co.kr/virtual/Recruit/GI_...
# 4   https://www.jobkorea.co.kr/virtual/Recruit/GI_...
# 5   https://www.jobkorea.co.kr/virtual/Recruit/GI_...
# 6   https://www.jobkorea.co.kr/virtual/Recruit/GI_...
# 7   https://www.jobkorea.co.kr/virtual/Recruit/GI_...
# 8   https://www.jobkorea.co.kr/virtual/Recruit/GI_...
# 9   https://www.jobkorea.co.kr/virtual/Recruit/GI_...
# 10  https://www.jobkorea.co.kr/virtual/Recruit/GI_...
# 11  https://www.jobkorea.co.kr/virtual/Recruit/GI_...
# 12  https://www.jobkorea.co.kr/virtual/Recruit/GI_...
# 13  https://www.jobkorea.co.kr/virtual/Recruit/GI_...
# 14  https://www.jobkorea.co.kr/virtual/Recruit/GI_...
# 15  https://www.jobkorea.co.kr/virtual/Recruit/GI_...
# 16  https://www.jobkorea.co.kr/virtual/Recruit/GI_...
# 17  https://www.jobkorea.co.kr/virtual/Recruit/GI_...
# 18  https://www.jobkorea.co.kr/virtual/Recruit/GI_...
# 19  https://www.jobkorea.co.kr/virtual/Recruit/GI_...
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None

# %%
df.to_csv("data_saramin.csv")
